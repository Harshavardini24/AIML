# %% [markdown]
# <a href="https://colab.research.google.com/github/Harshavardini24/AIML/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
x = 5
y = "John"
print(x)
print(y)
# Out:
# 5
# John

# %%
x = str(3)    # x will be '3'
y = int(3)    # y will be 3
z = float(3)  # z will be 3.0
print(x,y,z)
# Out:
# 3 3 3.0

# %%
x = 5
y = "John"
print(type(x))
print(type(y))
# Out:
# <class 'int'>
# <class 'str'>

# %%
x = "John"
# is the same as
x = 'John'
# x=2
print(x)
# Out:
# John

# %%
a = 4
A = "Sally"
#A will not overwrite a

# %%
myvar = "John"
my_var = "John"
_my_var = "John"
myVar = "John"
MYVAR = "John"
myvar2 = "John"

# %%
x, y, z = "Orange", "Banana", "Cherry"
print(x)
print(y)
print(z)
# Out:
# Orange
# Banana
# Cherry

# %%
x = y = z = "Orange"
print(x)
print(y)
print(z)
# Out:
# Orange
# Orange
# Orange

# %%
#list
fruits = ["apple", "banana", "cherry"]
x, y, z = fruits
print(x)
print(y)
print(fruits)
# Out:
# apple
# banana
# ['apple', 'banana', 'cherry']

# %%
thistuple = ("apple", "banana", "cherry", "apple", "cherry")
print(thistuple)
thistuple = ("apple", "banana", "cherry", "apple", "cherry", 3, 5, 6, 'grapes')
print(thistuple)
# Out:
# ('apple', 'banana', 'cherry', 'apple', 'cherry')
# ('apple', 'banana', 'cherry', 'apple', 'cherry', 3, 5, 6, 'grapes')

# %%
thisset = {"banana", "apple", "cherry", False, 1, 2}

print(thisset)
# Out:
# {False, 1, 2, 'apple', 'banana', 'cherry'}

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
print(thisdict)
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 1964}

# %%
x = "Python "
y = "is "
z = "awesome"
print(x + y + z)
# Out:
# Python is awesome

# %%
x = 5
y = "John"
print(x, y)
# Out:
# 5 John

# %%
import sys

print(sys.version)
# Out:
# 3.11.12 (main, Apr  9 2025, 08:55:54) [GCC 11.4.0]

# %%
if 5 > 2:
  print("Five is greater than two!")
# Out:
# Five is greater than two!

# %%
if 5 > 2:
 print("Five is greater than two!")
 if 5 > 1:
        print("Five is greater than two!")
# Out:
# Five is greater than two!
# Five is greater than two!

# %%
a = 33
b = 33
if b > a:
  print("b is greater than a")
elif a == b:
  print("a and b are equal")
# Out:
# a and b are equal

# %%
a = 200
b = 33
if b > a:
  print("b is greater than a")
elif a == b:
  print("a and b are equal")
else:
  print("a is greater than b")
# Out:
# a is greater than b

# %%
i = 1
while i < 6:
  print(i)
  i += 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
fruits = ["apple", "banana", "cherry"]
for x in fruits:
  print(x)
# Out:
# apple
# banana
# cherry

# %%
for x in range(7):
  print(x)
else:
  print("Finally finished!")
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# Finally finished!

# %%
x = "awesome"

def myfunc():
  print("Python is " + x)

myfunc()
# Out:
# Python is awesome

# %%
x = "awesome"

def myfunc():
  x = "fantastic"
  print("Python is " + x)

myfunc()

print("Python is " + x)
# Out:
# Python is fantastic
# Python is awesome
